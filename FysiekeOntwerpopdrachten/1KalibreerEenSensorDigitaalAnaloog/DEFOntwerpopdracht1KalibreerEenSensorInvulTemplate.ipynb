# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 45     |  |
# | :-------------|:-------------|
# | Meike Ligtenberg| 6242545|
# | Pieter Otten| 6332463|
# | Vladimir Ristic| 6507468 |
#
# | Planning Groep: 45     |Tijdstip / Tijdspanne  |
# |---|---|
# | Sanity check | 11.00 |
# | 3x3x3 schetsen af | 11.30 |
# | Mijlpaal 1: Criteria opgesteld | 12.30 |
# | Pauze 1| 12.30-13.00 |
# | kalibratie opstelling ontwerpen en maken| 14.00 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 14.30 |
# | plek voor verbetering ontwerp en alle metingen af | 15.00 |
# | data analyse in vsc | 15.15 |
# | leerdoelen af (plek voor feedback) | 16.00 |
# | opruimen en  feedback geven| 17.00 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#
# ![Alt](DEF_E_f1_ideeen.jpg "analyse: ideeen")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |sensor kracht | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet alleen een detectie geven als een mens op de stoel zit, dus vanaf 35 kg tot 200 kg|
# |sensor kracht  | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet bestendig zijn tegen de maximale stand van de stoelverwarming, 50 celcius |
# |sensor kracht | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet binnen 1kg de 35 kg en 300 kg kunnen detecteren |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving| Criteria omschrijving: moet licht kunnen meten vanaf 100 tot 10000 lumen |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet op een interval van 100 lumen het lichtverschil kunnen aangeven  |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet bestendig zijn tegen de maximaale temperatuur die een laptop kan behalen, moet tegen 60 celcius graden kunnen |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet binnen elke minuut een meting kunnen doen |
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  | Criteria omschrijving: moet tussen 10 en 30 celcius kunnen meten|
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  |  Criteria omschrijving: moet in staat zijn om op een interval van 0.1 celsius te meten  |
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  | Criteria omschrijving: moet frequent metingen kunnen doen, binnen elke minuut |
#
# Groep 45 heeft gekozen voor sensor licht.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# linksboven is de opstelling van het circuit te zien. de metingen worden in een donkere kamer uitgevoerd. Als referentie zal er een telefoon naast de sensor liggen met de phyphox, deze telefoon zal de lumens waarmee de sensor blootgesteld vastleggen. Hierna wordt hetzelfde herhaald, deze keer in de zon.
#  ![Alt](opstelling_sensor_kallibratie_schets2.jpg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
# - lux per meter
# 2. Over welk bereik ga je deze variabelen veranderen?
# - van 100 tot 10000
# 3. Wat ga je allemaal meten?
# - donkere kamer, zaklamp en buiten licht
# 4. Hoeveel metingen ga je doen
# - 1 in donkere kamer, 10 van de zaklamp en 1 van buiten
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?
# - ja

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opstelling_in_de_doos.jpg "meetopstelling student")
#  ![Alt](opstelling_in_de_zon.jpg "meetopstelling student")
#  ![Alt](sensor_getest_tegen_hitte.jpg "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
meeting = np.array([25, 32, 40, 45, 50, 52, 55, 58, 94, 150, 200, 300])
Lumen = np.array([15, 23, 31, 41, 46, 49.5, 53.5, 57, 300, 410, 1170, 4100])
def func(x,a,b):
    return a*x**b

popt, cov = curve_fit(func, meeting, Lumen, )

x= np.linspace(0,380, 20000)
y = func(x, *popt)
y_u = Lumen*np.sqrt(4*(0.05/2.4)**2+(0.0014/0.0042)**2)
plt.figure()
plt.plot(x,y, 'r--', label="curve fit: a*x**b")
plt.errorbar(meeting, Lumen, xerr=2, yerr=y_u,fmt='k.', label="data", )
plt.xlabel("meetingen")
plt.ylabel("Lumen(lx)")
plt.legend()
plt.show()
print("a is %2e +- %0e" %(popt[0],np.sqrt(cov[0][0])))
print("b is %2e +- %0e" %(popt[1],np.sqrt(cov[1][1])))
print(0.0042*449**2.4)
print(0.0042*450**2.4)
print(np.sqrt(cov))
# Out:
# a is 1.015424e-04 +- 6.688624e-05
# b is 3.070306e+00 +- 1.162553e-01
# 9741.8291513885
# 9793.98249499768
# [[6.68862377e-05            nan]
#  [           nan 1.16255276e-01]]
# C:\Users\marti\AppData\Local\Temp\ipykernel_24180\2376520138.py:26: RuntimeWarning: invalid value encountered in sqrt
#   print(np.sqrt(cov))

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# we itereren niet, de metingen zijn voldoende om een conclusie te kunnen trekken

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De lichtsensor is niet geschikt. De sensor was bestendig tegen de gewenste maximaal warmte, is in staat om een interval van 100 tot 10000 lumen te meten, meet de lumen bij hoge waarde niet binnen een onzekerheid van 100 en de sensor is in staat om vele metingen te doen binnen een minuut.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# Kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.
#
#  ![Alt](opstelling_sensor_kallibratie_schets2.jpg "schets student")
#
#  ![Alt](opstelling_in_de_zon.jpg "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |sensor kracht | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet alleen een detectie geven als een mens op de stoel zit, dus vanaf 35 kg tot 200 kg|
# |sensor kracht  | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet bestendig zijn tegen de maximale stand van de stoelverwarming, 50 celcius |
# |sensor kracht | toepassing: detecteren van aanwezigheid mens op stoel in auto voor gordel en mogelijk stoel verwarming| Criteria omschrijving: moet binnen 1kg de 35 kg en 300 kg kunnen detecteren |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving| Criteria omschrijving: moet licht kunnen meten vanaf 100 tot 10000 lumen |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet op een interval van 100 lumen het lichtverschil kunnen aangeven  |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet bestendig zijn tegen de maximaale temperatuur die een laptop kan behalen, moet tegen 60 celcius graden kunnen |
# |sensor licht | toepassing omschrijving: licht meten voor laptop zodat de lichtintensiteit van het scherm mee verandert met het licht van de omgeving | Criteria omschrijving: moet binnen elke minuut een meting kunnen doen |
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  | Criteria omschrijving: moet tussen 10 en 30 celcius kunnen meten|
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  |  Criteria omschrijving: moet in staat zijn om op een interval van 0.1 celsius te meten  |
# |sensor temperatuur | toepassing omschrijving: kamertemperatuur meten voor de verwarming  | Criteria omschrijving: moet frequent metingen kunnen doen, binnen elke minuut |

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
#  ![Alt](opstelling_sensor_kallibratie_schets2.jpg "schets student")
#
#  ![Alt](opstelling_in_de_zon.jpg "meetopstelling student")
#
# # De code voor data analyse -> terugverwijzing

# %%
# Zet hier jouw data in een voor jou handig formaat
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
meeting = np.array([25, 32, 40, 45, 50, 52, 55, 58, 94, 150, 200, 300])
Lumen = np.array([15, 23, 31, 41, 46, 49.5, 53.5, 57, 300, 410, 1170, 4100])
def func(x,a,b):
    return a*x**b

popt, cov = curve_fit(func, meeting, Lumen, )

x= np.linspace(0,380, 20000)
y = func(x, *popt)
y_u = Lumen*np.sqrt(4*(0.05/2.4)**2+(0.0014/0.0042)**2)
plt.figure()
plt.plot(x,y, 'r--', label="curve fit: a*x**b")
plt.errorbar(meeting, Lumen, xerr=2, yerr=y_u,fmt='k.', label="data", )
plt.xlabel("meetingen")
plt.ylabel("Lumen(lx)")
plt.legend()
plt.show()
print("a is %2e +- %0e" %(popt[0],np.sqrt(cov[0][0])))
print("b is %2e +- %0e" %(popt[1],np.sqrt(cov[1][1])))
print(0.0042*449**2.4)
print(0.0042*450**2.4)
print(np.sqrt(cov))
# Out:
# a is 1.015424e-04 +- 6.688624e-05
# b is 3.070306e+00 +- 1.162553e-01
# 9741.8291513885
# 9793.98249499768
# [[6.68862377e-05            nan]
#  [           nan 1.16255276e-01]]
# C:\Users\marti\AppData\Local\Temp\ipykernel_24180\2376520138.py:26: RuntimeWarning: invalid value encountered in sqrt
#   print(np.sqrt(cov))

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De lichtsensor is niet geschikt. De sensor was bestendig tegen de gewenste maximaal warmte, is in staat om een interval van 100 tot 10000 lumen te meten, meet de lumen bij hoge waarde niet binnen een onzekerheid van 100 en de sensor is in staat om vele metingen te doen binnen een minuut.
